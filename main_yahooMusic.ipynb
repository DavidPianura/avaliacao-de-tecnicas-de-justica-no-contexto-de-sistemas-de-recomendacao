# %% [markdown]
# <center><h1>Yahoo Music</h1></center>

# %%
from src import *
import src
import numpy as np
from importlib import reload
import pandas as pd
reload(src)
import matplotlib.pyplot as plt
from math import sqrt

import warnings
warnings.filterwarnings('ignore')

# %%
def df_to_latex(df, legenda):
    latex = r'''\begin{table}[]
                \centering
                        '''
    latex = latex + df.to_latex(index=False, header=True, 
                                column_format='c'*len(df.columns.to_list()))
    latex = latex + r'''
                    \caption{%s}
                    \end{table}
                        ''' % legenda 
    return latex

# %% [markdown]
# ## Pré-processamento

# %% [markdown]
# #### Carregamento

# %%
df = pd.read_csv('data/raw/yahoo_music/dataset/ydata-ymusic-user-artist-ratings-v1_0.txt', sep='\t', names=['userId', 'artistId', 'rating'])

# %%
df
# Out:
#             userId  artistId  rating
# 0                1   1000125      90
# 1                1   1006373     100
# 2                1   1006978      90
# 3                1   1007035     100
# 4                1   1007098     100
# ...            ...       ...     ...
# 115579435  1948882   1043454      90
# 115579436  1948882   1097508      90
# 115579437  1948882   1098099      90
# 115579438  1948882   1098953      90
# 115579439  1948882   1099151      90
#
# [115579440 rows x 3 columns]

# %% [markdown]
# #### Cortando notas abaixo de 100

# %%
df = df[df['rating'] >= 200]
df.shape[0]
# Out:
# 330865

# %% [markdown]
# #### Metadados de itens

# %%
itens = pd.read_csv('data/raw/yahoo_music/dataset/ydata-ymusic-artist-names-v1_0.txt', 
                sep='\t', 
                names=['artistId', 'artistName'], 
               encoding='ISO-8859-1')

# %%
itens.shape[0]
# Out:
# 97956

# %%
itens['artistId'].nunique()
# Out:
# 97956

# %% [markdown]
# #### Gêneros obtidos com o DiscoGS

# %%
import json

with open('data/processed/yahoo_music/yahoo_music_genres.json', 'r', encoding='utf-8') as file:
    dic = json.load(file)

# %%
dic_tratado = {"artistId": dic.keys(), "genres": [value[1] for value in dic.values()]}

# %%
g = pd.DataFrame(dic_tratado)

# %%
g['artistId'] = g['artistId'].astype(int)

# %%
g
# Out:
#        artistId                  genres
# 0       1000001  [Hip Hop, Funk / Soul]
# 1       1000002         [Hip Hop, Rock]
# 2       1000003                  [Rock]
# 3       1000004             [Rock, Pop]
# 4       1000005            [Jazz, Rock]
# ...         ...                     ...
# 97949   1101110           [Funk / Soul]
# 97950   1101111               [Hip Hop]
# 97951   1101112                  [Rock]
# 97952   1101113            [Electronic]
# 97953   1101114                  [Rock]
#
# [97954 rows x 2 columns]

# %% [markdown]
# Número de gêneros presentes

# %%
g.explode('genres')['genres'].nunique()
# Out:
# 15

# %%
g.explode('genres')['genres'].unique()
# Out:
# array(['Hip Hop', 'Funk / Soul', 'Rock', 'Pop', 'Jazz', 'Electronic', nan,
#        'Latin', 'Folk, World, & Country', 'Stage & Screen', 'Classical',
#        'Reggae', 'Non-Music', 'Brass & Military', 'Blues', "Children's"],
#       dtype=object)

# %% [markdown]
# Pegando ID de artistas sem gêneros para tirar da base de ratings

# %%
artistas_sem_generos = g[g['genres'].str.len() == 0]['artistId'].to_list()

# %%
len(artistas_sem_generos)
# Out:
# 6654

# %% [markdown]
# Tirando artistas sem gêneros

# %%
g = g[g['genres'].str.len() != 0]

# %%
g.shape[0]
# Out:
# 91300

# %%
print(df_to_latex(g.head(), 'Primeiras 5 linhas do conjunto de metadados de artistas presentes no conjunto de dados Yahoo! Music com os gêneros obtidos pela API Discogs'))
# Out:
# \begin{table}[]
#                 \centering
#                         \begin{tabular}{cc}
# \toprule
# artistId & genres \\
# \midrule
# 1000001 & ['Hip Hop', 'Funk / Soul'] \\
# 1000002 & ['Hip Hop', 'Rock'] \\
# 1000003 & ['Rock'] \\
# 1000004 & ['Rock', 'Pop'] \\
# 1000005 & ['Jazz', 'Rock'] \\
# \bottomrule
# \end{tabular}
#
#                     \caption{Primeiras 5 linhas do conjunto de metadados de artistas presentes no conjunto de dados Yahoo! Music com os gêneros obtidos pela API Discogs}
#                     \end{table}

# %% [markdown]
# Deixando igual ao MovieLens

# %%
g['genres'] = g['genres'].str.join('|')

# %%
g.head()
# Out:
#    artistId               genres
# 0   1000001  Hip Hop|Funk / Soul
# 1   1000002         Hip Hop|Rock
# 2   1000003                 Rock
# 3   1000004             Rock|Pop
# 4   1000005            Jazz|Rock

# %% [markdown]
# #### Cruzando IDs de filmes com os gêneros

# %%
artistas_com_generos = pd.merge(itens, g, on='artistId', how='inner')

# %%
artistas_com_generos.to_csv('data/processed/yahoo_music/yahoo_music_artists_metadata_with_genres.csv', index=False, header=False)

# %% [markdown]
# #### Tirando artistas cujo gêneros não foram encontrados

# %%
artistas_sem_generos = g[g['genres'].str.len() == 0]['artistId'].to_list()

# %%
artistas_com_generos = pd.read_csv('data/processed/yahoo_music/yahoo_music_artists_metadata_with_genres.csv', 
                                   names=['artistId', 'artistName', 'genre'])

# %%
artistas_com_generos

# %%
df = df[~df['artistId'].isin(artistas_sem_generos)]

# %%
df
# Out:
#             userId  artistId  rating
# 1384            25   1007340     255
# 1405            25   1024052     255
# 1408            25   1029091     255
# 1409            25   1030393     255
# 7317            91   1019658     255
# ...            ...       ...     ...
# 115559634  1948570   1053387     255
# 115565373  1948674   1045704     255
# 115575698  1948815   1020036     255
# 115575705  1948815   1030710     255
# 115576524  1948827   1097613     255
#
# [330818 rows x 3 columns]

# %% [markdown]
# #### Cortando linhas por frequência de avaliações de usuários

# %%
f = df['userId'].value_counts()
f_mantain = f[f >= 100].index.to_list()

# %%
df[df['userId'].isin(f_mantain)].shape[0]
# Out:
# 112523

# %%
df = df[df['userId'].isin(f_mantain)]
df.shape[0]
# Out:
# 112523

# %%
df.columns

# %%
df.to_csv('data/processed/yahoo_music/yahoo_music_tratado.csv', index=False, header=None)

# %%
userColumn='userId'
itemColumn='artistId'
ratingColumn='rating'

# %%
loader = DataLoader(file_path='data/processed/yahoo_music/yahoo_music_tratado.csv',
                    separator=',',
                    header=['userId', 'artistId', 'rating'],
                    genre_data_path='data/processed/yahoo_music/yahoo_music_artists_metadata_with_genres.csv',
                    genre_data_separator=',',
                    genre_data_header=['artistId', 'artistName', 'genres'],
                    genre_item_column='artistId',
                    genre_genre_column='genres',
                    genre_genre_separator='|',
                    genre_data_encoding='ISO-8859-1'
                    )
# Out:
# 24/09/08 19:23:45 WARN Utils: Your hostname, david-Nitro resolves to a loopback address: 127.0.1.1; using 192.168.15.14 instead (on interface wlp9s0)
# 24/09/08 19:23:45 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/09/08 19:23:45 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 24/09/08 19:23:46 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 24/09/08 19:23:46 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.

# %%
df = loader.load_data()
df_pandas = loader.convert_to_pandas(df)
genres_map = loader.get_genre_map()
# (train, test) = loader.train_test_separator(df)

# %%
df_pandas

# %% [markdown]
# ## ALS

# %%
kfold = KFOLD(df_pandas, 'FC', userColumn, itemColumn, ratingColumn, genres_map)
# Out:
# 24/09/08 19:23:51 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
results = kfold.run_cross_validation()
# Out:
# 1) Running FC
# ******************************
# Lambda = 0.0
# Reseting metrics lists
# ********************
# FAIRNESS MEASURE: kullback-leibler
# =====1º Fold=====
# Train/test spliting
# Instantiating ALS...
# 24/09/08 19:23:57 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.
# 24/09/08 19:24:00 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.VectorBLAS
# 24/09/08 19:24:01 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.3791073237901159
# CALCULATING MACE
# MACE = 0.06705780069010832
# CALCULATING MAP
# MAP = 0.024789734075448364
# CALCULATING MRR
# MRR = 0.02538548752834467
# =====2º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.3298222912716863
# CALCULATING MACE
# MACE = 0.0626631309182721
# CALCULATING MAP
# MAP = 0.011092558235415379
# CALCULATING MRR
# MRR = 0.011092558235415379
# =====3º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.36188538956723904
# CALCULATING MACE
# MACE = 0.06380782903596617
# CALCULATING MAP
# MAP = 0.020983302411873843
# CALCULATING MRR
# MRR = 0.021153370439084725
# =====4º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.3647647644461712
# CALCULATING MACE
# MACE = 0.06290833697401464
# CALCULATING MAP
# MAP = 0.021547103689960833
# CALCULATING MRR
# MRR = 0.02143166357452072
# =====5º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.35566825305488264
# CALCULATING MACE
# MACE = 0.06462854984520568
# CALCULATING MAP
# MAP = 0.013437435580292723
# CALCULATING MRR
# MRR = 0.013827045969903114
# ===============
# Getting mean and stdev
# MACE Mean = 0.06421312949271338
# MACE Error = 0.0017701677779531865
# MRMC Mean = 0.358249604426019
# MRMC Error = 0.018065756341961545
# MAP Mean = 0.01837002679859823
# MAP Error = 0.005818669808041034
# MRR Mean = 0.018578025149453718
# MRR Error = 0.005910186497640009
# Appending to results
#
#
# Reseting metrics lists
# ********************
# FAIRNESS MEASURE: hellinger
# =====1º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.7421521974775498
# CALCULATING MACE
# MACE = 0.06705780069010832
# CALCULATING MAP
# MAP = 0.024789734075448364
# CALCULATING MRR
# MRR = 0.02538548752834467
# =====2º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.6898637097836107
# CALCULATING MACE
# MACE = 0.0626631309182721
# CALCULATING MAP
# MAP = 0.011092558235415379
# CALCULATING MRR
# MRR = 0.011092558235415379
# =====3º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.7137559008347735
# CALCULATING MACE
# MACE = 0.06380782903596617
# CALCULATING MAP
# MAP = 0.020983302411873843
# CALCULATING MRR
# MRR = 0.021153370439084725
# =====4º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.7291073605793911
# CALCULATING MACE
# MACE = 0.06290833697401464
# CALCULATING MAP
# MAP = 0.021547103689960833
# CALCULATING MRR
# MRR = 0.02143166357452072
# =====5º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.7199703879526154
# CALCULATING MACE
# MACE = 0.06462854984520568
# CALCULATING MAP
# MAP = 0.013437435580292723
# CALCULATING MRR
# MRR = 0.013827045969903114
# ===============
# Getting mean and stdev
# MACE Mean = 0.06421312949271338
# MACE Error = 0.0017701677779531865
# MRMC Mean = 0.7189699113255881
# MRMC Error = 0.019464994834873624
# MAP Mean = 0.01837002679859823
# MAP Error = 0.005818669808041034
# MRR Mean = 0.018578025149453718
# MRR Error = 0.005910186497640009
# Appending to results
#
#
# Reseting metrics lists
# ********************
# FAIRNESS MEASURE: pearson
# =====1º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.3800271370547284
# CALCULATING MACE
# MACE = 0.06705780069010832
# CALCULATING MAP
# MAP = 0.024789734075448364
# CALCULATING MRR
# MRR = 0.02538548752834467
# =====2º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.32624076997136897
# CALCULATING MACE
# MACE = 0.0626631309182721
# CALCULATING MAP
# MAP = 0.011092558235415379
# CALCULATING MRR
# MRR = 0.011092558235415379
# =====3º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.371868300461384
# CALCULATING MACE
# MACE = 0.06380782903596617
# CALCULATING MAP
# MAP = 0.020983302411873843
# CALCULATING MRR
# MRR = 0.021153370439084725
# =====4º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.3729000179194408
# CALCULATING MACE
# MACE = 0.06290833697401464
# CALCULATING MAP
# MAP = 0.021547103689960833
# CALCULATING MRR
# MRR = 0.02143166357452072
# =====5º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.3521060465320073
# CALCULATING MACE
# MACE = 0.06462854984520568
# CALCULATING MAP
# MAP = 0.013437435580292723
# CALCULATING MRR
# MRR = 0.013827045969903114
# ===============
# Getting mean and stdev
# MACE Mean = 0.06421312949271338
# MACE Error = 0.0017701677779531865
# MRMC Mean = 0.3606284543877859
# MRMC Error = 0.021842496283996923
# MAP Mean = 0.01837002679859823
# MAP Error = 0.005818669808041034
# MRR Mean = 0.018578025149453718
# MRR Error = 0.005910186497640009
# Appending to results
#
#
# ******************************
# Lambda = 0.1
# Reseting metrics lists
# ********************
# FAIRNESS MEASURE: kullback-leibler
# =====1º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.250386999948705
# CALCULATING MACE
# MACE = 0.05394584774103817
# CALCULATING MAP
# MAP = 0.021714079571222428
# CALCULATING MRR
# MRR = 0.021689342403628117
# =====2º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.2474471799989491
# CALCULATING MACE
# MACE = 0.054305062883889914
# CALCULATING MAP
# MAP = 0.011587301587301585
# CALCULATING MRR
# MRR = 0.011587301587301585
# =====3º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.24933902783320006
# CALCULATING MACE
# MACE = 0.05264297427324032
# CALCULATING MAP
# MAP = 0.023938363224077507
# CALCULATING MRR
# MRR = 0.023974438260152543
# =====4º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.259638730523678
# CALCULATING MACE
# MACE = 0.05222192472379474
# CALCULATING MAP
# MAP = 0.020968872397443824
# CALCULATING MRR
# MRR = 0.021142032570603996
# =====5º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.2851490438690821
# CALCULATING MACE
# MACE = 0.0574247669972444
# CALCULATING MAP
# MAP = 0.013134405277262421
# CALCULATING MRR
# MRR = 0.013350855493712637
# ===============
# Getting mean and stdev
# MACE Mean = 0.05410811532384151
# MACE Error = 0.0020475381993009063
# MRMC Mean = 0.25839219643472283
# MRMC Error = 0.015678960019299838
# MAP Mean = 0.018268604411461553
# MAP Error = 0.0055296636299965235
# MRR Mean = 0.018348794063079776
# MRR Error = 0.005506961223094993
# Appending to results
#
#
# Reseting metrics lists
# ********************
# FAIRNESS MEASURE: hellinger
# =====1º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.7039627490956085
# CALCULATING MACE
# MACE = 0.06287765108880136
# CALCULATING MAP
# MAP = 0.023987837559266128
# CALCULATING MRR
# MRR = 0.024800041228612655
# =====2º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.6605709036326489
# CALCULATING MACE
# MACE = 0.059549097775636654
# CALCULATING MAP
# MAP = 0.01239125953411668
# CALCULATING MRR
# MRR = 0.01239125953411668
# =====3º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.6792160785115959
# CALCULATING MACE
# MACE = 0.06003668985592818
# CALCULATING MAP
# MAP = 0.020833848690991547
# CALCULATING MRR
# MRR = 0.02093279736136879
# =====4º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.6882247148096723
# CALCULATING MACE
# MACE = 0.058509911759279665
# CALCULATING MAP
# MAP = 0.023472479901051328
# CALCULATING MRR
# MRR = 0.023472479901051328
# =====5º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.7020707000754787
# CALCULATING MACE
# MACE = 0.06269787668151315
# CALCULATING MAP
# MAP = 0.013700267985982274
# CALCULATING MRR
# MRR = 0.013981653267367554
# ===============
# Getting mean and stdev
# MACE Mean = 0.060734245432231805
# MACE Error = 0.0019550482430340825
# MRMC Mean = 0.686809029225001
# MRMC Error = 0.017855426369583566
# MAP Mean = 0.018877138734281592
# MAP Error = 0.005475667459705799
# MRR Mean = 0.0191156462585034
# MRR Error = 0.005616307607045444
# Appending to results
#
#
# Reseting metrics lists
# ********************
# FAIRNESS MEASURE: pearson
# =====1º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.08337168608930551
# CALCULATING MACE
# MACE = 0.04775889661667597
# CALCULATING MAP
# MAP = 0.02146980004122861
# CALCULATING MRR
# MRR = 0.02120387548958978
# =====2º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07819766037537121
# CALCULATING MACE
# MACE = 0.047514929706183394
# CALCULATING MAP
# MAP = 0.011676973819830964
# CALCULATING MRR
# MRR = 0.011850133992991136
# =====3º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07665916510146974
# CALCULATING MACE
# MACE = 0.049409087972995216
# CALCULATING MAP
# MAP = 0.031890331890331886
# CALCULATING MRR
# MRR = 0.03333848690991548
# =====4º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.08082777454456219
# CALCULATING MACE
# MACE = 0.0482602320746705
# CALCULATING MAP
# MAP = 0.014949494949494949
# CALCULATING MRR
# MRR = 0.014949494949494949
# =====5º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.08235256008858358
# CALCULATING MACE
# MACE = 0.047134800994057646
# CALCULATING MAP
# MAP = 0.018195217480931766
# CALCULATING MRR
# MRR = 0.0182312925170068
# ===============
# Getting mean and stdev
# MACE Mean = 0.048015589472916544
# MACE Error = 0.0008794924447195755
# MRMC Mean = 0.08028176923985844
# MRMC Error = 0.00281072291283446
# MAP Mean = 0.019636363636363636
# MAP Error = 0.007760746639350111
# MRR Mean = 0.019914656771799627
# MRR Error = 0.008282275883855763
# Appending to results
#
#
# ******************************
# Lambda = 0.2
# Reseting metrics lists
# ********************
# FAIRNESS MEASURE: kullback-leibler
# =====1º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.21038751215508134
# CALCULATING MACE
# MACE = 0.04998303043134883
# CALCULATING MAP
# MAP = 0.021336837765409192
# CALCULATING MRR
# MRR = 0.021048237476808902
# =====2º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.20983255594379852
# CALCULATING MACE
# MACE = 0.05038580954119685
# CALCULATING MAP
# MAP = 0.011705833848690993
# CALCULATING MRR
# MRR = 0.01163368377654092
# =====3º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.20416653334544396
# CALCULATING MACE
# MACE = 0.0481111294964172
# CALCULATING MAP
# MAP = 0.02696918161203875
# CALCULATING MRR
# MRR = 0.027881880024737165
# =====4º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.2188478347418064
# CALCULATING MACE
# MACE = 0.04800731101923132
# CALCULATING MAP
# MAP = 0.026997526283240564
# CALCULATING MRR
# MRR = 0.027062461348175634
# =====5º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.2404279182885291
# CALCULATING MACE
# MACE = 0.05289738112743366
# CALCULATING MAP
# MAP = 0.01117604617604618
# CALCULATING MRR
# MRR = 0.011363636363636366
# ===============
# Getting mean and stdev
# MACE Mean = 0.049876932323125574
# MACE Error = 0.0020004291573230723
# MRMC Mean = 0.21673247089493186
# MRMC Error = 0.014245342270618732
# MAP Mean = 0.019637085137085137
# MAP Error = 0.007831328413516645
# MRR Mean = 0.019797979797979797
# MRR Error = 0.008023078555437893
# Appending to results
#
#
# Reseting metrics lists
# ********************
# FAIRNESS MEASURE: hellinger
# =====1º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.6687336037236598
# CALCULATING MACE
# MACE = 0.059084324008856784
# CALCULATING MAP
# MAP = 0.0239764996907854
# CALCULATING MRR
# MRR = 0.024644403215831782
# =====2º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.6424321270519916
# CALCULATING MACE
# MACE = 0.05765077491005847
# CALCULATING MAP
# MAP = 0.012521129663986809
# CALCULATING MRR
# MRR = 0.012521129663986809
# =====3º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.6542952019623935
# CALCULATING MACE
# MACE = 0.05742498670781134
# CALCULATING MAP
# MAP = 0.025629767058338485
# CALCULATING MRR
# MRR = 0.026427540713254996
# =====4º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.6651194235855293
# CALCULATING MACE
# MACE = 0.056077198645889316
# CALCULATING MAP
# MAP = 0.02226757369614513
# CALCULATING MRR
# MRR = 0.02226757369614513
# =====5º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.6861960795422405
# CALCULATING MACE
# MACE = 0.06101776130725724
# CALCULATING MAP
# MAP = 0.013635332921047207
# CALCULATING MRR
# MRR = 0.013851783137497424
# ===============
# Getting mean and stdev
# MACE Mean = 0.058251009115974625
# MACE Error = 0.0018786549363346721
# MRMC Mean = 0.6633552871731629
# MRMC Error = 0.01638294872518889
# MAP Mean = 0.019606060606060606
# MAP Error = 0.0060892377332416505
# MRR Mean = 0.019942486085343228
# MRR Error = 0.006358914690389229
# Appending to results
#
#
# Reseting metrics lists
# ********************
# FAIRNESS MEASURE: pearson
# =====1º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07909671577331416
# CALCULATING MACE
# MACE = 0.047761349683031015
# CALCULATING MAP
# MAP = 0.022263450834879402
# CALCULATING MRR
# MRR = 0.021997526283240566
# =====2º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07342791135139243
# CALCULATING MACE
# MACE = 0.047960352681944575
# CALCULATING MAP
# MAP = 0.01196763553906411
# CALCULATING MRR
# MRR = 0.01196763553906411
# =====3º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07274416463119338
# CALCULATING MACE
# MACE = 0.04933070540095646
# CALCULATING MAP
# MAP = 0.031061636775922486
# CALCULATING MRR
# MRR = 0.03308699237270665
# =====4º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07703212692495981
# CALCULATING MACE
# MACE = 0.04829009934447711
# CALCULATING MAP
# MAP = 0.015140177283034427
# CALCULATING MRR
# MRR = 0.015140177283034427
# =====5º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07648941194376717
# CALCULATING MACE
# MACE = 0.04750164460957515
# CALCULATING MAP
# MAP = 0.01888785817357246
# CALCULATING MRR
# MRR = 0.01890641104926819
# ===============
# Getting mean and stdev
# MACE Mean = 0.04816883034399687
# MACE Error = 0.0007105103882622219
# MRMC Mean = 0.07575806612492539
# MRMC Error = 0.002637133983425315
# MAP Mean = 0.019864151721294573
# MAP Error = 0.007361459759890546
# MRR Mean = 0.020219748505462785
# MRR Error = 0.008129433037642547
# Appending to results
#
#
# ******************************
# Lambda = 0.30000000000000004
# Reseting metrics lists
# ********************
# FAIRNESS MEASURE: kullback-leibler
# =====1º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.18477818952767902
# CALCULATING MACE
# MACE = 0.04720093323167594
# CALCULATING MAP
# MAP = 0.02530406101834673
# CALCULATING MRR
# MRR = 0.024976293547722114
# =====2º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.18703601537718625
# CALCULATING MACE
# MACE = 0.04781001110441187
# CALCULATING MAP
# MAP = 0.014952587095444234
# CALCULATING MRR
# MRR = 0.015962688105545245
# =====3º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.17945277736978343
# CALCULATING MACE
# MACE = 0.045609639804040356
# CALCULATING MAP
# MAP = 0.03848845598845598
# CALCULATING MRR
# MRR = 0.04021645021645021
# =====4º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.18981975568759626
# CALCULATING MACE
# MACE = 0.04518171583593017
# CALCULATING MAP
# MAP = 0.0210235003092146
# CALCULATING MRR
# MRR = 0.0210235003092146
# =====5º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.20552767013628778
# CALCULATING MACE
# MACE = 0.04919884800244229
# CALCULATING MAP
# MAP = 0.012990105132962277
# CALCULATING MRR
# MRR = 0.012881880024737167
# ===============
# Getting mean and stdev
# MACE Mean = 0.047000229595700126
# MACE Error = 0.0016409359526617627
# MRMC Mean = 0.18932288161970656
# MRMC Error = 0.009825286204906846
# MAP Mean = 0.022551741908884766
# MAP Error = 0.010161959582612318
# MRR Mean = 0.02301216244073387
# MRR Error = 0.010678457474967715
# Appending to results
#
#
# Reseting metrics lists
# ********************
# FAIRNESS MEASURE: hellinger
# =====1º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.6369642907181556
# CALCULATING MACE
# MACE = 0.05568593712126767
# CALCULATING MAP
# MAP = 0.024895897753040602
# CALCULATING MRR
# MRR = 0.02547309833024118
# =====2º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.6198226437112344
# CALCULATING MACE
# MACE = 0.05532412354839698
# CALCULATING MAP
# MAP = 0.012323232323232323
# CALCULATING MRR
# MRR = 0.012323232323232323
# =====3º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.6247796579541003
# CALCULATING MACE
# MACE = 0.05436477091842897
# CALCULATING MAP
# MAP = 0.024169243454957738
# CALCULATING MRR
# MRR = 0.02440424654710369
# =====4º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.6379393914563884
# CALCULATING MACE
# MACE = 0.05333015600014718
# CALCULATING MAP
# MAP = 0.024771181199752627
# CALCULATING MRR
# MRR = 0.024771181199752627
# =====5º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.6678296135375751
# CALCULATING MACE
# MACE = 0.05905271303774182
# CALCULATING MAP
# MAP = 0.01344465058750773
# CALCULATING MRR
# MRR = 0.013632240775097918
# ===============
# Getting mean and stdev
# MACE Mean = 0.05555154012519653
# MACE Error = 0.002160495382814439
# MRMC Mean = 0.6374671194754907
# MRMC Error = 0.018672547550518136
# MAP Mean = 0.0199208410636982
# MAP Error = 0.006441867218298481
# MRR Mean = 0.020120799835085544
# MRR Error = 0.0065483684901211
# Appending to results
#
#
# Reseting metrics lists
# ********************
# FAIRNESS MEASURE: pearson
# =====1º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07750207024002034
# CALCULATING MACE
# MACE = 0.04750151012414643
# CALCULATING MAP
# MAP = 0.022119150690579258
# CALCULATING MRR
# MRR = 0.021791383219954646
# =====2º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07219021197674683
# CALCULATING MACE
# MACE = 0.047857057057953366
# CALCULATING MAP
# MAP = 0.012351061636775924
# CALCULATING MRR
# MRR = 0.012351061636775924
# =====3º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07140902332951783
# CALCULATING MACE
# MACE = 0.048887290067743894
# CALCULATING MAP
# MAP = 0.03093898165326736
# CALCULATING MRR
# MRR = 0.03299319727891156
# =====4º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07588067374418811
# CALCULATING MACE
# MACE = 0.04789047333343119
# CALCULATING MAP
# MAP = 0.015345289631003916
# CALCULATING MRR
# MRR = 0.015233972376829519
# =====5º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.0749598183886248
# CALCULATING MACE
# MACE = 0.04743035850008483
# CALCULATING MAP
# MAP = 0.018577612863327146
# CALCULATING MRR
# MRR = 0.018642547928262213
# ===============
# Getting mean and stdev
# MACE Mean = 0.04791333781667194
# MACE Error = 0.0005820533404134388
# MRMC Mean = 0.07438835953581958
# MRMC Error = 0.002547403491206313
# MAP Mean = 0.019866419294990723
# MAP Error = 0.007180854268580474
# MRR Mean = 0.020202432488146772
# MRR Error = 0.007982657582604519
# Appending to results
#
#
# ******************************
# Lambda = 0.4
# Reseting metrics lists
# ********************
# FAIRNESS MEASURE: kullback-leibler
# =====1º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.1672425171879272
# CALCULATING MACE
# MACE = 0.04498179668292302
# CALCULATING MAP
# MAP = 0.023573490002061426
# CALCULATING MRR
# MRR = 0.023443619872191294
# =====2º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.16970317331514634
# CALCULATING MACE
# MACE = 0.04576174242257424
# CALCULATING MAP
# MAP = 0.012567511853226139
# CALCULATING MRR
# MRR = 0.013495155638012783
# =====3º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.1616363890414905
# CALCULATING MACE
# MACE = 0.04362997693208851
# CALCULATING MAP
# MAP = 0.04035662749948463
# CALCULATING MRR
# MRR = 0.04222531436817149
# =====4º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.17029109213346524
# CALCULATING MACE
# MACE = 0.04319626453195371
# CALCULATING MAP
# MAP = 0.023721913007627292
# CALCULATING MRR
# MRR = 0.023656977942692232
# =====5º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.18097952954056604
# CALCULATING MACE
# MACE = 0.046488755169554995
# CALCULATING MAP
# MAP = 0.014869099154813444
# CALCULATING MRR
# MRR = 0.014782519068233354
# ===============
# Getting mean and stdev
# MACE Mean = 0.044811707147818895
# MACE Error = 0.001391952647215765
# MRMC Mean = 0.16997054024371908
# MRMC Error = 0.0070404593241695755
# MAP Mean = 0.023017728303442585
# MAP Error = 0.01092072975299762
# MRR Mean = 0.023520717377860233
# MRR Error = 0.01147556597117032
# Appending to results
#
#
# Reseting metrics lists
# ********************
# FAIRNESS MEASURE: hellinger
# =====1º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.6043871884792209
# CALCULATING MACE
# MACE = 0.05234103629339559
# CALCULATING MAP
# MAP = 0.026115233972376826
# CALCULATING MRR
# MRR = 0.026028653885796737
# =====2º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.5980925349168251
# CALCULATING MACE
# MACE = 0.053046871958433786
# CALCULATING MAP
# MAP = 0.012236652236652237
# CALCULATING MRR
# MRR = 0.012236652236652237
# =====3º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.5937738642663962
# CALCULATING MACE
# MACE = 0.051304264011201015
# CALCULATING MAP
# MAP = 0.026560502989074416
# CALCULATING MRR
# MRR = 0.026654298082869513
# =====4º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.6102444364017927
# CALCULATING MACE
# MACE = 0.050536157528769846
# CALCULATING MAP
# MAP = 0.02505978148835292
# CALCULATING MRR
# MRR = 0.025232941661513093
# =====5º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.6468143227158827
# CALCULATING MACE
# MACE = 0.056869279750858266
# CALCULATING MAP
# MAP = 0.013512677798392082
# CALCULATING MRR
# MRR = 0.013700267985982272
# ===============
# Getting mean and stdev
# MACE Mean = 0.052819521908531696
# MACE Error = 0.002459214025697867
# MRMC Mean = 0.6106624693560235
# MRMC Error = 0.02115265135074962
# MAP Mean = 0.020696969696969696
# MAP Error = 0.007175718757834062
# MRR Mean = 0.02077056277056277
# MRR Error = 0.007158829969161199
# Appending to results
#
#
# Reseting metrics lists
# ********************
# FAIRNESS MEASURE: pearson
# =====1º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07682481043619108
# CALCULATING MACE
# MACE = 0.047173534402327424
# CALCULATING MAP
# MAP = 0.020921459492888067
# CALCULATING MRR
# MRR = 0.020593692022263455
# =====2º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.0717135851963373
# CALCULATING MACE
# MACE = 0.047580435608124694
# CALCULATING MAP
# MAP = 0.012676767676767677
# CALCULATING MRR
# MRR = 0.012676767676767677
# =====3º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07083467960276425
# CALCULATING MACE
# MACE = 0.04848541614220801
# CALCULATING MAP
# MAP = 0.0308740465883323
# CALCULATING MRR
# MRR = 0.032964337250051524
# =====4º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.0750237241083168
# CALCULATING MACE
# MACE = 0.047429128234059634
# CALCULATING MAP
# MAP = 0.01567305710162853
# CALCULATING MRR
# MRR = 0.015561739847454133
# =====5º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07395905930572926
# CALCULATING MACE
# MACE = 0.04715055086711217
# CALCULATING MAP
# MAP = 0.019079571222428364
# CALCULATING MRR
# MRR = 0.01914450628736343
# ===============
# Getting mean and stdev
# MACE Mean = 0.04756381305076639
# MACE Error = 0.0005456353231062886
# MRMC Mean = 0.07367117172986774
# MRMC Error = 0.002435957045299862
# MAP Mean = 0.019844980416408985
# MAP Error = 0.006931327020963504
# MRR Mean = 0.020188208616780043
# MRR Error = 0.007783141275656207
# Appending to results
#
#
# ******************************
# Lambda = 0.5
# Reseting metrics lists
# ********************
# FAIRNESS MEASURE: kullback-leibler
# =====1º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.1539311071871321
# CALCULATING MACE
# MACE = 0.04314830755881934
# CALCULATING MAP
# MAP = 0.024631003916718196
# CALCULATING MRR
# MRR = 0.024652648938363223
# =====2º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.15408719675976618
# CALCULATING MACE
# MACE = 0.043796495092809945
# CALCULATING MAP
# MAP = 0.012920016491445061
# CALCULATING MRR
# MRR = 0.013352916924345495
# =====3º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.14793773851145703
# CALCULATING MACE
# MACE = 0.04191851162397541
# CALCULATING MAP
# MAP = 0.040742115027829304
# CALCULATING MRR
# MRR = 0.04300453514739229
# =====4º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.1535762029596029
# CALCULATING MACE
# MACE = 0.041572137188604356
# CALCULATING MAP
# MAP = 0.02010307153164296
# CALCULATING MRR
# MRR = 0.019929911358482787
# =====5º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.16257259346311534
# CALCULATING MACE
# MACE = 0.04416289578816671
# CALCULATING MAP
# MAP = 0.01612347969490827
# CALCULATING MRR
# MRR = 0.015968872397443826
# ===============
# Getting mean and stdev
# MACE Mean = 0.04291966945047516
# MACE Error = 0.0011385155366438033
# MRMC Mean = 0.1544209677762147
# MRMC Error = 0.005233217392825642
# MAP Mean = 0.022903937332508756
# MAP Error = 0.0108935929890751
# MRR Mean = 0.023381776953205525
# MRR Error = 0.011769795221938995
# Appending to results
#
#
# Reseting metrics lists
# ********************
# FAIRNESS MEASURE: hellinger
# =====1º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.5759859186759563
# CALCULATING MACE
# MACE = 0.04947001672357289
# CALCULATING MAP
# MAP = 0.02631106988249845
# CALCULATING MRR
# MRR = 0.025935889507318077
# =====2º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.5779217629785507
# CALCULATING MACE
# MACE = 0.05088128911333728
# CALCULATING MAP
# MAP = 0.011676973819830964
# CALCULATING MRR
# MRR = 0.01163368377654092
# =====3º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.5588487357447803
# CALCULATING MACE
# MACE = 0.04765794209904887
# CALCULATING MAP
# MAP = 0.03002216037930323
# CALCULATING MRR
# MRR = 0.03013090084518656
# =====4º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.5804527686051564
# CALCULATING MACE
# MACE = 0.04761230011538206
# CALCULATING MAP
# MAP = 0.0228447742733457
# CALCULATING MRR
# MRR = 0.022909709338280765
# =====5º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.6222245969743808
# CALCULATING MACE
# MACE = 0.05427246514338187
# CALCULATING MAP
# MAP = 0.013313749742321171
# CALCULATING MRR
# MRR = 0.013501339929911357
# ===============
# Getting mean and stdev
# MACE Mean = 0.049978802638944594
# MACE Error = 0.0027611415431767457
# MRMC Mean = 0.5830867565957649
# MRMC Error = 0.023469603507722
# MAP Mean = 0.020833745619459908
# MAP Error = 0.008044704638934709
# MRR Mean = 0.020822304679447536
# MRR Error = 0.007987228078933914
# Appending to results
#
#
# Reseting metrics lists
# ********************
# FAIRNESS MEASURE: pearson
# =====1º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07613973410180663
# CALCULATING MACE
# MACE = 0.04664845969309165
# CALCULATING MAP
# MAP = 0.022353123067408772
# CALCULATING MRR
# MRR = 0.02208719851576994
# =====2º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07130494944345654
# CALCULATING MACE
# MACE = 0.04721524529077269
# CALCULATING MAP
# MAP = 0.0126984126984127
# CALCULATING MRR
# MRR = 0.0126984126984127
# =====3º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07045238991424009
# CALCULATING MACE
# MACE = 0.04808048836463148
# CALCULATING MAP
# MAP = 0.03186971758400329
# CALCULATING MRR
# MRR = 0.033960008245722526
# =====4º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07460423090215088
# CALCULATING MACE
# MACE = 0.04713334364061197
# CALCULATING MAP
# MAP = 0.016326530612244896
# CALCULATING MRR
# MRR = 0.0162152133580705
# =====5º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07338074881888715
# CALCULATING MACE
# MACE = 0.046820945267413656
# CALCULATING MAP
# MAP = 0.018537414965986394
# CALCULATING MRR
# MRR = 0.01860235003092146
# ===============
# Getting mean and stdev
# MACE Mean = 0.04717969645130429
# MACE Error = 0.0005535687128490687
# MRMC Mean = 0.07317641063610825
# MRMC Error = 0.0023336862822683864
# MAP Mean = 0.020357039785611212
# MAP Error = 0.007326948650342395
# MRR Mean = 0.020712636569779425
# MRR Error = 0.008159200113148843
# Appending to results
#
#
# ******************************
# Lambda = 0.6000000000000001
# Reseting metrics lists
# ********************
# FAIRNESS MEASURE: kullback-leibler
# =====1º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.14384449626867069
# CALCULATING MACE
# MACE = 0.04183836708084669
# CALCULATING MAP
# MAP = 0.02376314162028448
# CALCULATING MRR
# MRR = 0.023907441764584626
# =====2º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.14267926051901633
# CALCULATING MACE
# MACE = 0.04216941211744909
# CALCULATING MAP
# MAP = 0.015381364667078953
# CALCULATING MRR
# MRR = 0.015381364667078953
# =====3º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.13753444152448316
# CALCULATING MACE
# MACE = 0.040619461433080976
# CALCULATING MAP
# MAP = 0.03900226757369614
# CALCULATING MRR
# MRR = 0.04094001236858379
# =====4º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.14155135517254847
# CALCULATING MACE
# MACE = 0.040307298532826934
# CALCULATING MAP
# MAP = 0.02056586270871985
# CALCULATING MRR
# MRR = 0.02045763760049474
# =====5º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.14815433178083395
# CALCULATING MACE
# MACE = 0.042207903155566176
# CALCULATING MAP
# MAP = 0.01611214182642754
# CALCULATING MRR
# MRR = 0.016047206761492478
# ===============
# Getting mean and stdev
# MACE Mean = 0.04142848846395397
# MACE Error = 0.0008994508325555122
# MRMC Mean = 0.1427527770531105
# MRMC Error = 0.0038421507397363966
# MAP Mean = 0.022964955679241394
# MAP Error = 0.00959244534801701
# MRR Mean = 0.023346732632446916
# MRR Error = 0.01042730695665138
# Appending to results
#
#
# Reseting metrics lists
# ********************
# FAIRNESS MEASURE: hellinger
# =====1º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.5486913943021227
# CALCULATING MACE
# MACE = 0.046669976781716284
# CALCULATING MAP
# MAP = 0.024082663368377652
# CALCULATING MRR
# MRR = 0.023743558029272315
# =====2º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.5497055588984431
# CALCULATING MACE
# MACE = 0.047889334183200336
# CALCULATING MAP
# MAP = 0.012679859822716964
# CALCULATING MRR
# MRR = 0.012607709750566893
# =====3º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.5323642496091935
# CALCULATING MACE
# MACE = 0.04471221570862494
# CALCULATING MAP
# MAP = 0.025580808080808072
# CALCULATING MRR
# MRR = 0.026666666666666658
# =====4º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.5500413734230121
# CALCULATING MACE
# MACE = 0.04463342800388806
# CALCULATING MAP
# MAP = 0.023502370645227786
# CALCULATING MRR
# MRR = 0.023567305710162852
# =====5º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.5941286773752904
# CALCULATING MACE
# MACE = 0.0514127563380699
# CALCULATING MAP
# MAP = 0.011157493300350447
# CALCULATING MRR
# MRR = 0.011345083487940633
# ===============
# Getting mean and stdev
# MACE Mean = 0.047063542203099905
# MACE Error = 0.0027922518256758657
# MRMC Mean = 0.5549862507216125
# MRMC Error = 0.023107613645941116
# MAP Mean = 0.019400639043496183
# MAP Error = 0.006893082915473552
# MRR Mean = 0.01958606472892187
# MRR Error = 0.007068966758163867
# Appending to results
#
#
# Reseting metrics lists
# ********************
# FAIRNESS MEASURE: pearson
# =====1º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07584036354180375
# CALCULATING MACE
# MACE = 0.046174515586031556
# CALCULATING MAP
# MAP = 0.022439703153988865
# CALCULATING MRR
# MRR = 0.022173778602350026
# =====2º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07105326279033294
# CALCULATING MACE
# MACE = 0.046826413127734355
# CALCULATING MAP
# MAP = 0.012987012987012988
# CALCULATING MRR
# MRR = 0.012987012987012988
# =====3º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07015274325926772
# CALCULATING MACE
# MACE = 0.04753123317800192
# CALCULATING MAP
# MAP = 0.03245001030715316
# CALCULATING MRR
# MRR = 0.033559059987631416
# =====4º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07423300770779666
# CALCULATING MACE
# MACE = 0.04672135591097998
# CALCULATING MAP
# MAP = 0.016579055864770147
# CALCULATING MRR
# MRR = 0.01646773861059575
# =====5º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07290515502993246
# CALCULATING MACE
# MACE = 0.0464932067709683
# CALCULATING MAP
# MAP = 0.019003298289012573
# CALCULATING MRR
# MRR = 0.01906823335394764
# ===============
# Getting mean and stdev
# MACE Mean = 0.046749344914743224
# MACE Error = 0.0005035145618178717
# MRMC Mean = 0.07283690646582672
# MRMC Error = 0.002310877962601174
# MAP Mean = 0.020691816120387545
# MAP Error = 0.007423613007273413
# MRR Mean = 0.020851164708307564
# MRR Error = 0.007865717716886628
# Appending to results
#
#
# ******************************
# Lambda = 0.7000000000000001
# Reseting metrics lists
# ********************
# FAIRNESS MEASURE: kullback-leibler
# =====1º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.13485113353221895
# CALCULATING MACE
# MACE = 0.040527743631425056
# CALCULATING MAP
# MAP = 0.02771645021645021
# CALCULATING MRR
# MRR = 0.02742939600082457
# =====2º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.1317102377961395
# CALCULATING MACE
# MACE = 0.04064498084325516
# CALCULATING MAP
# MAP = 0.016503813646670785
# CALCULATING MRR
# MRR = 0.016503813646670785
# =====3º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.12861710280517816
# CALCULATING MACE
# MACE = 0.03937830079319499
# CALCULATING MAP
# MAP = 0.03792001649144505
# CALCULATING MRR
# MRR = 0.03987322201607915
# =====4º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.13181728457831757
# CALCULATING MACE
# MACE = 0.0391587289468621
# CALCULATING MAP
# MAP = 0.019804679447536593
# CALCULATING MRR
# MRR = 0.019678416821273966
# =====5º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.13546513692894582
# CALCULATING MACE
# MACE = 0.04051010211011324
# CALCULATING MAP
# MAP = 0.017012987012987014
# CALCULATING MRR
# MRR = 0.01687384044526902
# ===============
# Getting mean and stdev
# MACE Mean = 0.040043971264970106
# MACE Error = 0.0007140198385360512
# MRMC Mean = 0.13249217912815997
# MRMC Error = 0.002760718899795209
# MAP Mean = 0.023791589363017934
# MAP Error = 0.009082587203378064
# MRR Mean = 0.0240717377860235
# MRR Error = 0.009865916627035527
# Appending to results
#
#
# Reseting metrics lists
# ********************
# FAIRNESS MEASURE: hellinger
# =====1º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.5177123861325531
# CALCULATING MACE
# MACE = 0.043404657996072585
# CALCULATING MAP
# MAP = 0.0204700061842919
# CALCULATING MRR
# MRR = 0.020296846011131728
# =====2º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.5221602588128522
# CALCULATING MACE
# MACE = 0.04480187668570033
# CALCULATING MAP
# MAP = 0.01546794475365904
# CALCULATING MRR
# MRR = 0.01539579468150897
# =====3º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.5030754352864257
# CALCULATING MACE
# MACE = 0.041482450661752074
# CALCULATING MAP
# MAP = 0.030559678416821265
# CALCULATING MRR
# MRR = 0.03324572253143681
# =====4º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.5149046117670086
# CALCULATING MACE
# MACE = 0.04122014378142489
# CALCULATING MAP
# MAP = 0.029482580911152335
# CALCULATING MRR
# MRR = 0.02980725623582766
# =====5º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.5555965954964559
# CALCULATING MACE
# MACE = 0.04748824759484535
# CALCULATING MAP
# MAP = 0.01269428983714698
# CALCULATING MRR
# MRR = 0.012881880024737167
# ===============
# Getting mean and stdev
# MACE Mean = 0.043679475343959044
# MACE Error = 0.002584438265584363
# MRMC Mean = 0.5226898574990593
# MRMC Error = 0.019705612851710505
# MAP Mean = 0.021734900020614303
# MAP Error = 0.008070170229746817
# MRR Mean = 0.022325499896928468
# MRR Error = 0.008895871901524091
# Appending to results
#
#
# Reseting metrics lists
# ********************
# FAIRNESS MEASURE: pearson
# =====1º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07559120447951868
# CALCULATING MACE
# MACE = 0.045656211770364184
# CALCULATING MAP
# MAP = 0.0212502576788291
# CALCULATING MRR
# MRR = 0.021030715316429596
# =====2º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07080670712411384
# CALCULATING MACE
# MACE = 0.04634459189306781
# CALCULATING MAP
# MAP = 0.013220985363842508
# CALCULATING MRR
# MRR = 0.013220985363842508
# =====3º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.06997144499301947
# CALCULATING MACE
# MACE = 0.047062129033591006
# CALCULATING MAP
# MAP = 0.032364460935889496
# CALCULATING MRR
# MRR = 0.034512471655328794
# =====4º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07406493648916915
# CALCULATING MACE
# MACE = 0.04629269338577661
# CALCULATING MAP
# MAP = 0.015933828076685218
# CALCULATING MRR
# MRR = 0.015933828076685218
# =====5º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07262360115065437
# CALCULATING MACE
# MACE = 0.04593072466154059
# CALCULATING MAP
# MAP = 0.018971346114203255
# CALCULATING MRR
# MRR = 0.019252731395588536
# ===============
# Getting mean and stdev
# MACE Mean = 0.04625727014886803
# MACE Error = 0.0005302312813066277
# MRMC Mean = 0.0726115788472951
# MRMC Error = 0.0023031733860484293
# MAP Mean = 0.020348175633889916
# MAP Error = 0.007371971064484568
# MRR Mean = 0.02079014636157493
# MRR Error = 0.008240141915662372
# Appending to results
#
#
# ******************************
# Lambda = 0.8
# Reseting metrics lists
# ********************
# FAIRNESS MEASURE: kullback-leibler
# =====1º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.12562768590138604
# CALCULATING MACE
# MACE = 0.039115744057261544
# CALCULATING MAP
# MAP = 0.027660791589363017
# CALCULATING MRR
# MRR = 0.02730055658627087
# =====2º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.12222016003752519
# CALCULATING MACE
# MACE = 0.03913639518171977
# CALCULATING MAP
# MAP = 0.013847660276231704
# CALCULATING MRR
# MRR = 0.013847660276231704
# =====3º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.12059223659217809
# CALCULATING MACE
# MACE = 0.03823733430045633
# CALCULATING MAP
# MAP = 0.039372294372294364
# CALCULATING MRR
# MRR = 0.041325499896928464
# =====4º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.12334815383408429
# CALCULATING MACE
# MACE = 0.03813510480904182
# CALCULATING MAP
# MAP = 0.018928056070913215
# CALCULATING MRR
# MRR = 0.01881673881673882
# =====5º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.12550459497794555
# CALCULATING MACE
# MACE = 0.03892842667967778
# CALCULATING MAP
# MAP = 0.01709699031127602
# CALCULATING MRR
# MRR = 0.017035662749948464
# ===============
# Getting mean and stdev
# MACE Mean = 0.03871060100563145
# MACE Error = 0.00048684362054592366
# MRMC Mean = 0.12345856626862384
# MRMC Error = 0.0021594559600511434
# MAP Mean = 0.023381158524015667
# MAP Error = 0.010298545592903554
# MRR Mean = 0.02366522366522366
# MRR Error = 0.01105604400519433
# Appending to results
#
#
# Reseting metrics lists
# ********************
# FAIRNESS MEASURE: hellinger
# =====1º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.4857914490468364
# CALCULATING MACE
# MACE = 0.04001088564659268
# CALCULATING MAP
# MAP = 0.02523139558853844
# CALCULATING MRR
# MRR = 0.02491754277468563
# =====2º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.4873855506027938
# CALCULATING MACE
# MACE = 0.04079279383284212
# CALCULATING MAP
# MAP = 0.014605236033807461
# CALCULATING MRR
# MRR = 0.015532879818594102
# =====3º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.47080555268080726
# CALCULATING MACE
# MACE = 0.03793858845741724
# CALCULATING MAP
# MAP = 0.043201401772830335
# CALCULATING MRR
# MRR = 0.04558235415378273
# =====4º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.48201721487301696
# CALCULATING MACE
# MACE = 0.038060017797004866
# CALCULATING MAP
# MAP = 0.02453927025355597
# CALCULATING MRR
# MRR = 0.02551329622758194
# =====5º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.5098316496866329
# CALCULATING MACE
# MACE = 0.04248008063621745
# CALCULATING MAP
# MAP = 0.018553906411049266
# CALCULATING MRR
# MRR = 0.01827767470624613
# ===============
# Getting mean and stdev
# MACE Mean = 0.03985647327401487
# MACE Error = 0.0019163369622346065
# MRMC Mean = 0.48716628337801743
# MRMC Error = 0.014228874629372465
# MAP Mean = 0.025226242011956296
# MAP Error = 0.010964763512544868
# MRR Mean = 0.025964749536178104
# MRR Error = 0.011769302106215134
# Appending to results
#
#
# Reseting metrics lists
# ********************
# FAIRNESS MEASURE: pearson
# =====1º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07536597659856391
# CALCULATING MACE
# MACE = 0.04494556684537015
# CALCULATING MAP
# MAP = 0.02073077715934859
# CALCULATING MRR
# MRR = 0.020619459905174192
# =====2º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07067526628445045
# CALCULATING MACE
# MACE = 0.04574767653542757
# CALCULATING MAP
# MAP = 0.013740465883323024
# CALCULATING MRR
# MRR = 0.013740465883323024
# =====3º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.06983740877893807
# CALCULATING MACE
# MACE = 0.04667482025718808
# CALCULATING MAP
# MAP = 0.03189136260564831
# CALCULATING MRR
# MRR = 0.03507833436404864
# =====4º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07376212782017968
# CALCULATING MACE
# MACE = 0.04574260106452136
# CALCULATING MAP
# MAP = 0.016316223459080598
# CALCULATING MRR
# MRR = 0.01628736343022057
# =====5º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.0724384889601322
# CALCULATING MACE
# MACE = 0.04532281005697909
# CALCULATING MAP
# MAP = 0.018964131106988247
# CALCULATING MRR
# MRR = 0.01924551638837353
# ===============
# Getting mean and stdev
# MACE Mean = 0.045686694951897255
# MACE Error = 0.0006451586922898798
# MRMC Mean = 0.07241585368845285
# MRMC Error = 0.0022468986537234757
# MAP Mean = 0.020328592042877753
# MAP Error = 0.00698612334465983
# MRR Mean = 0.020994227994227992
# MRR Error = 0.008311620395911903
# Appending to results
#
#
# ******************************
# Lambda = 0.9
# Reseting metrics lists
# ********************
# FAIRNESS MEASURE: kullback-leibler
# =====1º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.11534920882634421
# CALCULATING MACE
# MACE = 0.03725045798165135
# CALCULATING MAP
# MAP = 0.027271696557410834
# CALCULATING MRR
# MRR = 0.027185116470830748
# =====2º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.1140392942941143
# CALCULATING MACE
# MACE = 0.03745157130057044
# CALCULATING MAP
# MAP = 0.014007421150278294
# CALCULATING MRR
# MRR = 0.013920841063698208
# =====3º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.11206886961691734
# CALCULATING MACE
# MACE = 0.03724734287418923
# CALCULATING MAP
# MAP = 0.037868480725623585
# CALCULATING MRR
# MRR = 0.04134817563388992
# =====4º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.1158285709007647
# CALCULATING MACE
# MACE = 0.036992045468231136
# CALCULATING MAP
# MAP = 0.017884972170686454
# CALCULATING MRR
# MRR = 0.017856112141826426
# =====5º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.1144226813048027
# CALCULATING MACE
# MACE = 0.03691144478872767
# CALCULATING MAP
# MAP = 0.019209441352298497
# CALCULATING MRR
# MRR = 0.019245516388373535
# ===============
# Getting mean and stdev
# MACE Mean = 0.037170572482673955
# MACE Error = 0.00021809102358607353
# MRMC Mean = 0.11434172498858866
# MRMC Error = 0.0014568479879970009
# MAP Mean = 0.023248402391259533
# MAP Error = 0.009492219323631555
# MRR Mean = 0.023911152339723764
# MRR Error = 0.010874357596125346
# Appending to results
#
#
# Reseting metrics lists
# ********************
# FAIRNESS MEASURE: hellinger
# =====1º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.44687637613856884
# CALCULATING MACE
# MACE = 0.03566276151611393
# CALCULATING MAP
# MAP = 0.02376623376623377
# CALCULATING MRR
# MRR = 0.02359307359307359
# =====2º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.44500505410981006
# CALCULATING MACE
# MACE = 0.03571774453541361
# CALCULATING MAP
# MAP = 0.019043496186353332
# CALCULATING MRR
# MRR = 0.019043496186353332
# =====3º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.4338390923079168
# CALCULATING MACE
# MACE = 0.033970723406446024
# CALCULATING MAP
# MAP = 0.04071325499896928
# CALCULATING MRR
# MRR = 0.04312306740878169
# =====4º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.4434555562939851
# CALCULATING MACE
# MACE = 0.03418465205506326
# CALCULATING MAP
# MAP = 0.02085034013605442
# CALCULATING MRR
# MRR = 0.021777983920841064
# =====5º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.4521938841967695
# CALCULATING MACE
# MACE = 0.03598535378640618
# CALCULATING MAP
# MAP = 0.016366213151927437
# CALCULATING MRR
# MRR = 0.016211090496804782
# ===============
# Getting mean and stdev
# MACE Mean = 0.035104247059888606
# MACE Error = 0.0009480502966109294
# MRMC Mean = 0.44427399260941003
# MRMC Error = 0.006700531993995726
# MAP Mean = 0.024147907647907647
# MAP Error = 0.009644171101060504
# MRR Mean = 0.024749742321170894
# MRR Error = 0.010644460122998118
# Appending to results
#
#
# Reseting metrics lists
# ********************
# FAIRNESS MEASURE: pearson
# =====1º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.0753218718134385
# CALCULATING MACE
# MACE = 0.0442930228386929
# CALCULATING MAP
# MAP = 0.02192176870748299
# CALCULATING MRR
# MRR = 0.021622345908060194
# =====2º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07046997819596457
# CALCULATING MACE
# MACE = 0.044982394369054
# CALCULATING MAP
# MAP = 0.011398680684394973
# CALCULATING MRR
# MRR = 0.012326324469181613
# =====3º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.06956389896290423
# CALCULATING MACE
# MACE = 0.046087138676783955
# CALCULATING MAP
# MAP = 0.03340960626674912
# CALCULATING MRR
# MRR = 0.03621418264275406
# =====4º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07355993743483946
# CALCULATING MACE
# MACE = 0.045040822695455604
# CALCULATING MAP
# MAP = 0.016741908884766024
# CALCULATING MRR
# MRR = 0.016741908884766024
# =====5º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07213668605482498
# CALCULATING MACE
# MACE = 0.044378288527359006
# CALCULATING MAP
# MAP = 0.019663986806843947
# CALCULATING MRR
# MRR = 0.019880437023294163
# ===============
# Getting mean and stdev
# MACE Mean = 0.04495633342146909
# MACE Error = 0.0007177490795335677
# MRMC Mean = 0.07221047449239434
# MRMC Error = 0.002320612938812392
# MAP Mean = 0.02062719027004741
# MAP Error = 0.008158655734406082
# MRR Mean = 0.02135703978561121
# MRR Error = 0.009025501222815473
# Appending to results
#
#
# ******************************
# Lambda = 1.0
# Reseting metrics lists
# ********************
# FAIRNESS MEASURE: kullback-leibler
# =====1º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.10804398696177257
# CALCULATING MACE
# MACE = 0.03595272212574726
# CALCULATING MAP
# MAP = 0.0269222840651412
# CALCULATING MRR
# MRR = 0.02674190888476602
# =====2º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.10690373084070554
# CALCULATING MACE
# MACE = 0.03634930956888222
# CALCULATING MAP
# MAP = 0.012239744382601525
# CALCULATING MRR
# MRR = 0.012239744382601525
# =====3º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.10540337900060022
# CALCULATING MACE
# MACE = 0.036609793019374844
# CALCULATING MAP
# MAP = 0.043767264481550196
# CALCULATING MRR
# MRR = 0.04598330241187383
# =====4º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.10820955470684311
# CALCULATING MACE
# MACE = 0.036221449551827156
# CALCULATING MAP
# MAP = 0.016697588126159554
# CALCULATING MRR
# MRR = 0.016697588126159554
# =====5º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.1048694274748923
# CALCULATING MACE
# MACE = 0.03537608535477888
# CALCULATING MAP
# MAP = 0.021098742527313953
# CALCULATING MRR
# MRR = 0.021098742527313953
# ===============
# Getting mean and stdev
# MACE Mean = 0.03610187192412207
# MACE Error = 0.00046971263627057296
# MRMC Mean = 0.10668601579696275
# MRMC Error = 0.0015130934057347718
# MAP Mean = 0.024145124716553286
# MAP Error = 0.01223953950940083
# MRR Mean = 0.024552257266542976
# MRR Error = 0.013127307750511755
# Appending to results
#
#
# Reseting metrics lists
# ********************
# FAIRNESS MEASURE: hellinger
# =====1º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.40031055747763916
# CALCULATING MACE
# MACE = 0.030280794273511335
# CALCULATING MAP
# MAP = 0.027332508761080176
# CALCULATING MRR
# MRR = 0.026870748299319718
# =====2º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.40045559013517723
# CALCULATING MACE
# MACE = 0.030325734969517484
# CALCULATING MAP
# MAP = 0.012841682127396413
# CALCULATING MRR
# MRR = 0.013491032776747063
# =====3º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.39872407386564634
# CALCULATING MACE
# MACE = 0.030558116874983488
# CALCULATING MAP
# MAP = 0.04518759018759018
# CALCULATING MRR
# MRR = 0.04730571016285301
# =====4º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.4002327209040004
# CALCULATING MACE
# MACE = 0.030118822063401548
# CALCULATING MAP
# MAP = 0.020958565244279533
# CALCULATING MRR
# MRR = 0.021023500309214592
# =====5º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.3943211727462258
# CALCULATING MACE
# MACE = 0.029398239199489723
# CALCULATING MAP
# MAP = 0.023108122036693456
# CALCULATING MRR
# MRR = 0.02298185941043083
# ===============
# Getting mean and stdev
# MACE Mean = 0.030136341476180717
# MACE Error = 0.00044151242725735837
# MRMC Mean = 0.3988088230257378
# MRMC Error = 0.0026048378498392225
# MAP Mean = 0.02588569367140795
# MAP Error = 0.012008270263747445
# MRR Mean = 0.026334570191713043
# MRR Error = 0.01269331305118526
# Appending to results
#
#
# Reseting metrics lists
# ********************
# FAIRNESS MEASURE: pearson
# =====1º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07506225710599648
# CALCULATING MACE
# MACE = 0.04328758518621563
# CALCULATING MAP
# MAP = 0.02196093588950732
# CALCULATING MRR
# MRR = 0.021553287981859407
# =====2º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07033178826537397
# CALCULATING MACE
# MACE = 0.04393710516620132
# CALCULATING MAP
# MAP = 0.011535765821480108
# CALCULATING MRR
# MRR = 0.01246340960626675
# =====3º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.06938982434483021
# CALCULATING MACE
# MACE = 0.04528566868910397
# CALCULATING MAP
# MAP = 0.035058750773036475
# CALCULATING MRR
# MRR = 0.03685219542362398
# =====4º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.07335005951932896
# CALCULATING MACE
# MACE = 0.04422075721416369
# CALCULATING MAP
# MAP = 0.016853226138940428
# CALCULATING MRR
# MRR = 0.016853226138940428
# =====5º Fold=====
# Train/test spliting
# Instantiating ALS...
# Getting n = 100 predictions for each user
# Calibrating...
# CALCULATING MRMC
# MRMC = 0.0717792079702206
# CALCULATING MACE
# MACE = 0.04320718990563301
# CALCULATING MAP
# MAP = 0.020995670995670988
# CALCULATING MRR
# MRR = 0.02114718614718614
# ===============
# Getting mean and stdev
# MACE Mean = 0.043987661232263525
# MACE Error = 0.0008427566333986244
# MRMC Mean = 0.07198262744115004
# MRMC Error = 0.0022827213322452926
# MAP Mean = 0.02128086992372706
# MAP Error = 0.008731335984440385
# MRR Mean = 0.021773861059575343
# MRR Error = 0.00920182991867744
# Appending to results

# %%
results
# Out:
#     Lambda   FairnessMeasure Statistic      MACE      MRMC       MAP       MRR
# 0      0.0  kullback-leibler      mean  0.064213  0.358250  0.018370  0.018578
# 1      0.0  kullback-leibler     stdev  0.000792  0.008079  0.002602  0.002643
# 0      0.0         hellinger      mean  0.064213  0.718970  0.018370  0.018578
# 1      0.0         hellinger     stdev  0.000792  0.008705  0.002602  0.002643
# 0      0.0           pearson      mean  0.064213  0.360628  0.018370  0.018578
# ..     ...               ...       ...       ...       ...       ...       ...
# 1      1.0  kullback-leibler     stdev  0.000210  0.000677  0.005474  0.005871
# 0      1.0         hellinger      mean  0.030136  0.398809  0.025886  0.026335
# 1      1.0         hellinger     stdev  0.000197  0.001165  0.005370  0.005677
# 0      1.0           pearson      mean  0.043988  0.071983  0.021281  0.021774
# 1      1.0           pearson     stdev  0.000377  0.001021  0.003905  0.004115
#
# [66 rows x 7 columns]

# %%
results.to_csv('results/yahoo_music/results_yahoo_music2.csv', index=False)

# %%
results = pd.read_csv('results/yahoo_music/results_yahoo_music.csv')

# %%
#results.to_csv('results/yahoo_movies/results_yahoo_movies.csv', index=False)

# %%
tradeoff_weights = results['Lambda'].drop_duplicates().to_list()
mrmc_kl = results[(results['FairnessMeasure'] == 'kullback-leibler') & (results['Statistic'] == 'mean')]['MAP'].to_list()
mrmc_he = results[(results['FairnessMeasure'] == 'hellinger') & (results['Statistic'] == 'mean')]['MAP'].to_list()
mrmc_pe = results[(results['FairnessMeasure'] == 'pearson') & (results['Statistic'] == 'mean')]['MAP'].to_list()

# Plotando o gráfico
plt.figure(figsize=(10, 6))
plt.plot(tradeoff_weights, mrmc_kl, marker='o', linestyle='-', color='b', label='Kullback-Leibler')
plt.plot(tradeoff_weights, mrmc_he, marker='s', linestyle='-', color='r', label='Hellinger')
plt.plot(tradeoff_weights, mrmc_pe, marker='^', linestyle='-', color='g', label='Pearson chi-quadrado')

plt.xlabel('λ')
plt.xticks(np.arange(0.0, 1.1, 0.1))
plt.ylabel('Mean rank miscalibration (MRMC)')
plt.title('MovieLens com ALS')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### CRIANDO GRÁFICOS

# %%
def show_graphic(dataset_name, metric, title):
    short_metric = metric[metric.find('(')+1: metric.find(')')]
    tradeoff_weights = results['Lambda'].drop_duplicates().to_list()
    mrmc_kl = results[(results['FairnessMeasure'] == 'kullback-leibler') & (results['Statistic'] == 'mean')][short_metric].to_list()
    mrmc_he = results[(results['FairnessMeasure'] == 'hellinger') & (results['Statistic'] == 'mean')][short_metric].to_list()
    mrmc_pe = results[(results['FairnessMeasure'] == 'pearson') & (results['Statistic'] == 'mean')][short_metric].to_list()

    mrmc_he_err = results[(results['FairnessMeasure'] == 'hellinger') & (results['Statistic'] == 'stdev')][short_metric].to_list()
    mrmc_he_err = [std/sqrt(5) for std in mrmc_he_err]
    mrmc_kl_err = results[(results['FairnessMeasure'] == 'kullback-leibler') & (results['Statistic'] == 'stdev')][short_metric].to_list()
    mrmc_kl_err = [std/sqrt(5) for std in mrmc_kl_err]
    mrmc_pe_err = results[(results['FairnessMeasure'] == 'pearson') & (results['Statistic'] == 'stdev')][short_metric].to_list()
    mrmc_pe_err = [std/sqrt(5) for std in mrmc_pe_err]
    
    # Plotando o gráfico com barras de erro
    plt.figure(figsize=(10, 6))
    plt.errorbar(tradeoff_weights, mrmc_kl, yerr=mrmc_kl_err, marker='o', linestyle='-', color='b', label='Kullback-Leibler', capsize=5) 
    plt.errorbar(tradeoff_weights, mrmc_he, yerr=mrmc_he_err, marker='s', linestyle='-', color='r', label='Hellinger', capsize=5) 
    plt.errorbar(tradeoff_weights, mrmc_pe, yerr=mrmc_pe_err, marker='^', linestyle='-', color='g', label='Pearson chi-quadrado', capsize=5)
    
    # Configurando os rótulos e título
    plt.xlabel(r'$\lambda$')
    plt.ylabel(metric)
    plt.title(title)
    
    # Definindo os valores do eixo x para incrementar de 0.1 em 0.1
    plt.xticks(np.arange(0.0, 1.1, 0.1))
    
    plt.legend()
    plt.grid(True)
    #plt.savefig(f'results/{dataset_name}/graphs/{dataset_name}_{metric}.pgf'.replace(' ', '_'))
    plt.savefig(f'results/{dataset_name}/graphs/{dataset_name}_{metric}.pdf'.replace(' ', '_'), bbox_inches='tight')
    plt.show()

# %%
for metric in ['Mean Average Calibration Error (MACE)', 'Mean Rank Miscalibration (MRMC)', 'Mean Average Precision (MAP)', 'Mean Reciprocal Rank (MRR)']:
    print('=' * 10 + metric + '=' * 10)
    show_graphic('yahoo_music', metric, 'Yahoo Music com ALS')
# Out:
# ==========Mean Average Calibration Error (MACE)==========
# ==========Mean Rank Miscalibration (MRMC)==========
# ==========Mean Average Precision (MAP)==========
# ==========Mean Reciprocal Rank (MRR)==========

# %%
predictions_user_map

# %%
distributions = Distributions(train.toPandas(), userColumn, itemColumn, genres_map)

# %%
distributions.show_userProfileDist_userRecDist(predictions_user_map, 305)

# %% [markdown]
# # FBC-kNN

# %%
df_genres = loader.genre_data

# %%
df_genres

# %%
df_expanded = df_genres['genres'].str.get_dummies(sep='|')

# %%
df_final = pd.concat([df_genres[['item']], df_expanded], axis=1)

# %%
df_final.index = df_final['item']

# %%
df_mv_genres = df_final.drop(columns = ['item'])

# %%
df_mv_genres

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine_sim = cosine_similarity(df_mv_genres)

# %%
df_cosine_sim = pd.DataFrame(cosine_sim, index = df_mv_genres.index, columns = df_mv_genres.index)

# %%
df_cosine_sim

# %%
similar_itens = list(df_cosine_sim.loc[1].sort_values(ascending=False).keys())[:102]
similar_itens.remove(1)
#rated_by_u = set(df_pandas[(df_pandas[userColumn] == 1) & (df_pandas[ratingColumn] > 0)][itemColumn].to_list())
#intersect = list(similar_itens.intersection(rated_by_u))[:101]

# %%
def get_recommendatinon(movieId, userId, df_sim, df_ratings, k):
    similar_itens = list(df_sim.loc[movieId].sort_values(ascending=False).keys())[:k+2]
    similar_itens.remove(movieId)
    return similar_itens()

# %%
#def get_recommendatinon(movieId, userId, df_sim, df_ratings, k):
#    similar_itens = set(df_sim.loc[movieId].sort_values(ascending=False).keys())
#    rated_by_u = set(df_ratings[(df_ratings[userColumn] == userId) & (df_ratings[ratingColumn] > 0)][itemColumn].to_list())
#    intersect = list(similar_itens.intersect(rated_by_u))[:k+1]
